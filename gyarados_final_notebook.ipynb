# %%
#libraries and dataframe
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_scatter_density
from sklearn.cluster import KMeans

import graphviz
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn import metrics

champs2 = pd.read_csv("../Datasets/2/champs.csv")
participants=pd.read_csv("../Datasets/2/participants.csv")

champs5= pd.read_csv("../Datasets/5/LoL-Champions.csv")
teambans=pd.read_csv("../Datasets/2/teambans.csv")
stats=pd.read_csv("../Datasets/2/stats1.csv")

dotaheronames=pd.read_csv("../Datasets/3/hero_names.csv")
dotaplayers=pd.read_csv("../Datasets/3/players.csv")
dotaheroesdata=pd.read_csv("../Datasets/6/heroes_data.csv")

plt.rcParams['figure.figsize'] = [7, 7]

# %%
# LOL ŞAMPİYONLAR
print(champs2.id.count(), "\nhero in champs2 ds")
champs2.head()
# Out:
# 138
# hero in champs2 ds
#        name   id
# 0       Jax   24
# 1      Sona   37
# 2  Tristana   18
# 3     Varus  110
# 4     Fiora  114

# %%
# DOTA ŞAMPİYONLAR
print(dotaheronames["localized_name"], "\ndota heros in dotaheronames ds")
# Out:
# 0           Anti-Mage
# 1                 Axe
# 2                Bane
# 3         Bloodseeker
# 4      Crystal Maiden
#             ...
# 107       Terrorblade
# 108           Phoenix
# 109            Oracle
# 110     Winter Wyvern
# 111        Arc Warden
# Name: localized_name, Length: 112, dtype: object
# dota heros in dotaheronames ds

# %%
stats.head()
# Out:
#    id  win  item1  item2  item3  item4  item5  item6  trinket  kills  ...  \
# 0   9    0   3748   2003   3111   3053   1419   1042     3340      6  ...
# 1  10    0   2301   3111   3190   3107      0      0     3364      0  ...
# 2  11    0   1055   3072   3006   3031   3046   1036     3340      7  ...
# 3  12    0   1029   3078   3156   1001   3053      0     3340      5  ...
# 4  13    0   3020   1058   3198   3102   1052   1026     3340      2  ...
#
#    neutralminionskilled  ownjunglekills  enemyjunglekills  totcctimedealt  \
# 0                    69              42                27             610
# 1                     1               1                 0             211
# 2                     3               1                 2             182
# 3                     6               6                 0             106
# 4                     4               3                 1             159
#
#    champlvl  pinksbought  wardsbought  wardsplaced  wardskilled  firstblood
# 0        13            0            0           10            0           0
# 1        14            1            0           17            3           0
# 2        14            1            0           13            5           0
# 3        15            0            0            3            0           0
# 4        15            0            0           10            0           0
#
# [5 rows x 56 columns]

# %%
participants.head()
# Out:
#    id  matchid  player  championid  ss1  ss2         role position
# 0   9       10       1          19    4   11         NONE   JUNGLE
# 1  10       10       2         267    3    4  DUO_SUPPORT      BOT
# 2  11       10       3         119    7    4    DUO_CARRY      BOT
# 3  12       10       4         114   12    4         SOLO      TOP
# 4  13       10       5         112    4    3         SOLO      MID

# %%
# LOL - CHAMPS2DEKİ BOŞ SATIRLAR KONTROLÜ
champs2.isnull().sum()
# Out:
# name    0
# id      0
# dtype: int64

# %%
# DOTA - dotaheronamesdeki BOŞ SATIRLAR KONTROLÜ
dotaheronames.isnull().sum()
# Out:
# name              0
# hero_id           0
# localized_name    0
# dtype: int64

# %%
# LOL - CHAMPS5DEN GELEN ŞAMPİYONLAR
print(champs5)
champs5=champs5.loc[:,"Id":"Class"]
champs5.head()
# Out:
#       Id     Name    Class  Style  Difficulty DamageType  Damage  Sturdiness  \
# 0      1   Aatrox  Warrior      3           2          P       3           3
# 1      2     Ahri     Mage     10           2          M       3           1
# 2      3    Akali  Assasin      7           2         PM       3           1
# 3      4  Alistar  Support      7           1          M       1           3
# 4      5    Amumu     Tank      9           1          M       2           3
# ..   ...      ...      ...    ...         ...        ...     ...         ...
# 140  141      Zed  Assasin      6           3          P       3           1
# 141  142    Ziggs     Mage      9           2          M       3           1
# 142  143   Zilean  Support     10           2          M       2           1
# 143  144      Zoe     Mage     10           3          M       3           1
# 144  145     Zyra  Support     10           2          M       3           1
#
#      Crowd-Control  Mobility  Functionality
# 0                2         2            2.0
# 1                2         3            1.0
# 2                1         3            1.0
# 3                3         1            2.0
# 4                3         1            1.0
# ..             ...       ...            ...
# 140              1         3            1.0
# 141              2         2            1.0
# 142              2         2            3.0
# 143              2         2            1.0
# 144              3         1            1.0
#
# [145 rows x 11 columns]
#    Id     Name    Class
# 0   1   Aatrox  Warrior
# 1   2     Ahri     Mage
# 2   3    Akali  Assasin
# 3   4  Alistar  Support
# 4   5    Amumu     Tank

# %%
# DOTA - dotaheroesdatadan GELEN ŞAMPİYONLAR
print(dotaheroesdata)
dotaheroesdata=dotaheroesdata.loc[:,"id":"roles"]
dotaheroesdata.head()
# Out:
#      Unnamed: 0   id                          name  localized_name  \
# 0             0    1        npc_dota_hero_antimage       Anti-Mage
# 1             1    2             npc_dota_hero_axe             Axe
# 2             2    3            npc_dota_hero_bane            Bane
# 3             3    4     npc_dota_hero_bloodseeker     Bloodseeker
# 4             4    5  npc_dota_hero_crystal_maiden  Crystal Maiden
# ..          ...  ...                           ...             ...
# 115         115  121      npc_dota_hero_grimstroke      Grimstroke
# 116         116  123        npc_dota_hero_hoodwink        Hoodwink
# 117         117  126     npc_dota_hero_void_spirit     Void Spirit
# 118         118  128        npc_dota_hero_snapfire        Snapfire
# 119         119  129            npc_dota_hero_mars            Mars
#
#     primary_attr attack_type  \
# 0            agi       Melee
# 1            str       Melee
# 2            int      Ranged
# 3            agi       Melee
# 4            int      Ranged
# ..           ...         ...
# 115          int      Ranged
# 116          agi      Ranged
# 117          int       Melee
# 118          str      Ranged
# 119          str       Melee
#
#                                                  roles  \
# 0                         ['Carry', 'Escape', 'Nuker']
# 1      ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2          ['Support', 'Disabler', 'Nuker', 'Durable']
# 3    ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4          ['Support', 'Disabler', 'Nuker', 'Jungler']
# ..                                                 ...
# 115         ['Support', 'Nuker', 'Disabler', 'Escape']
# 116                    ['Nuker', 'Escape', 'Disabler']
# 117           ['Carry', 'Escape', 'Nuker', 'Disabler']
# 118         ['Support', 'Nuker', 'Disabler', 'Escape']
# 119      ['Carry', 'Initiator', 'Disabler', 'Durable']
#
#                                                    img  \
# 0         /apps/dota2/images/heroes/antimage_full.png?
# 1              /apps/dota2/images/heroes/axe_full.png?
# 2             /apps/dota2/images/heroes/bane_full.png?
# 3      /apps/dota2/images/heroes/bloodseeker_full.png?
# 4    /apps/dota2/images/heroes/crystal_maiden_full....
# ..                                                 ...
# 115     /apps/dota2/images/heroes/grimstroke_full.png?
# 116       /apps/dota2/images/heroes/hoodwink_full.png?
# 117    /apps/dota2/images/heroes/void_spirit_full.png?
# 118       /apps/dota2/images/heroes/snapfire_full.png?
# 119           /apps/dota2/images/heroes/mars_full.png?
#
#                                                   icon  base_health  ...  \
# 0          /apps/dota2/images/heroes/antimage_icon.png          200  ...
# 1               /apps/dota2/images/heroes/axe_icon.png          200  ...
# 2              /apps/dota2/images/heroes/bane_icon.png          200  ...
# 3       /apps/dota2/images/heroes/bloodseeker_icon.png          200  ...
# 4    /apps/dota2/images/heroes/crystal_maiden_icon.png          200  ...
# ..                                                 ...          ...  ...
# 115      /apps/dota2/images/heroes/grimstroke_icon.png          200  ...
# 116        /apps/dota2/images/heroes/hoodwink_icon.png          200  ...
# 117     /apps/dota2/images/heroes/void_spirit_icon.png          200  ...
# 118        /apps/dota2/images/heroes/snapfire_icon.png          200  ...
# 119            /apps/dota2/images/heroes/mars_icon.png          200  ...
#
#      5_win  6_pick  6_win  7_pick  7_win  8_pick  8_win    winrate  lane  \
# 0    19911   17583   8610    7417   3591    1796    819  47.867144     1
# 1    14622   12186   5964    4676   2272     951    469  48.711569     3
# 2     3872    3900   2044    1962   1030     750    399  52.691740     5
# 3     5956    5636   2828    2479   1219     855    428  49.400120     1
# 4    19476   17692   9025    7684   3865    2386   1156  49.860973     5
# ..     ...     ...    ...     ...    ...     ...    ...        ...   ...
# 115  13142   13809   6571    6162   2900    2168    981  46.590636     5
# 116  18550   18797   9341    7843   3979    1755    895  50.781413     3
# 117  13107   14740   7377    7791   3931    3307   1687  50.621734     2
# 118   8298    8173   3735    3421   1593     787    356  46.316540     4
# 119  17006   18876   9120    8630   4167    3043   1408  47.759788     3
#
#         main_role
# 0        safelane
# 1         offlane
# 2    hard_support
# 3        safelane
# 4    hard_support
# ..            ...
# 115  hard_support
# 116       offlane
# 117           mid
# 118       support
# 119       offlane
#
# [120 rows x 55 columns]
#    id                          name  localized_name primary_attr attack_type  \
# 0   1        npc_dota_hero_antimage       Anti-Mage          agi       Melee
# 1   2             npc_dota_hero_axe             Axe          str       Melee
# 2   3            npc_dota_hero_bane            Bane          int      Ranged
# 3   4     npc_dota_hero_bloodseeker     Bloodseeker          agi       Melee
# 4   5  npc_dota_hero_crystal_maiden  Crystal Maiden          int      Ranged
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
# LOL - CHAMPS5DEKİ BOŞ SATIRLAR KONTROLÜ
champs5.isnull().sum()
# Out:
# Id       0
# Name     0
# Class    0
# dtype: int64

# %%
# DOTA - dotaheroesdatadaki BOŞ SATIRLAR KONTROLÜ
dotaheroesdata.isnull().sum()
# Out:
# id                0
# name              0
# localized_name    0
# primary_attr      0
# attack_type       0
# roles             0
# dtype: int64

# %%
# LOL - İSİMLER İLE CHAMPS2 VE CHAMPS5İ BİRLEŞTİRME
print("merged ds full join")
champs = pd.merge(champs2,champs5,how="outer",left_on="name",right_on="Name").drop("Id", axis=1)

print(champs[champs["name"].isnull()])
print("-----------------------------------------")
print(champs[champs["Name"].isnull()])

print("\n\n-----------left join-------------------\n\n")

print("merged ds left join")
champs = pd.merge(champs2,champs5,how="left",left_on="name",right_on="Name").drop("Id", axis=1)
print(champs[champs["name"].isnull()])
print("-----------------------------------------")
print(champs[champs["Name"].isnull()])
print(champs.count())
champs.head()
# Out:
# merged ds full join
#     name  id    Name     Class
# 138  NaN NaN  Kai Sa  Marksman
# 139  NaN NaN   Neeko      Mage
# 140  NaN NaN    Pyke   Support
# 141  NaN NaN  Qiyana   Warrior
# 142  NaN NaN   Sylas   Warrior
# 143  NaN NaN   Yuumi   Support
# 144  NaN NaN     Zoe      Mage
# -----------------------------------------
# Empty DataFrame
# Columns: [name, id, Name, Class]
# Index: []
#
#
# -----------left join-------------------
#
#
# merged ds left join
# Empty DataFrame
# Columns: [name, id, Name, Class]
# Index: []
# -----------------------------------------
# Empty DataFrame
# Columns: [name, id, Name, Class]
# Index: []
# name     138
# id       138
# Name     138
# Class    138
# dtype: int64
#        name   id      Name     Class
# 0       Jax   24       Jax   Warrior
# 1      Sona   37      Sona   Support
# 2  Tristana   18  Tristana  Marksman
# 3     Varus  110     Varus  Marksman
# 4     Fiora  114     Fiora   Warrior

# %%
# DOTA - KÜÇÜK TABLOYA BÜYÜKTEN CLASSLARI EKLEMECE
newdotachamps = pd.merge(dotaheroesdata,dotaheronames,how="right",left_on="localized_name",right_on="localized_name")
newdotachamps=newdotachamps.loc[:,["id","localized_name","roles"]]
print(newdotachamps)
# Out:
#       id  localized_name                                              roles
# 0      1       Anti-Mage                       ['Carry', 'Escape', 'Nuker']
# 1      2             Axe    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2      3            Bane        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3      4     Bloodseeker  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4      5  Crystal Maiden        ['Support', 'Disabler', 'Nuker', 'Jungler']
# ..   ...             ...                                                ...
# 107  109     Terrorblade                       ['Carry', 'Pusher', 'Nuker']
# 108  110         Phoenix  ['Support', 'Nuker', 'Initiator', 'Escape', 'D...
# 109  111          Oracle         ['Support', 'Nuker', 'Disabler', 'Escape']
# 110  112   Winter Wyvern                   ['Support', 'Disabler', 'Nuker']
# 111  113      Arc Warden                       ['Carry', 'Escape', 'Nuker']
#
# [112 rows x 3 columns]

# %%
# LOL - KARAKTERLERİN OYUN TİPLERİ CHAMPS'E SÜTUN OLARAK EKLENDİ
GameStyle = []
for iter in champs["Class"]:

    if (iter == "Mage" or iter == "Marksman" or iter == "Assasin" or iter == "Warrior"):
        GameStyle.append("Aggressive")
    else:
        GameStyle.append("Supportive")
champs["GameStyle"]=GameStyle
print(champs)
# Out:
#           name   id       Name     Class   GameStyle
# 0          Jax   24        Jax   Warrior  Aggressive
# 1         Sona   37       Sona   Support  Supportive
# 2     Tristana   18   Tristana  Marksman  Aggressive
# 3        Varus  110      Varus  Marksman  Aggressive
# 4        Fiora  114      Fiora   Warrior  Aggressive
# ..         ...  ...        ...       ...         ...
# 133       Shen   98       Shen      Tank  Supportive
# 134  Jarvan IV   59  Jarvan IV   Warrior  Aggressive
# 135   Malzahar   90   Malzahar      Mage  Aggressive
# 136        Zac  154        Zac   Warrior  Aggressive
# 137     Gragas   79     Gragas   Warrior  Aggressive
#
# [138 rows x 5 columns]

# %%
# DOTA - KARAKTERLERİN OYUN TİPLERİ CHAMPS'E SÜTUN OLARAK EKLENDİ
GameStyle2 = []
for iter in newdotachamps["roles"]:
    iter = iter.split("'")
    iter = iter[1]
    if (iter=="Carry" or iter=="Nuker" or iter=="Escape" or iter=="Pusher"):
        GameStyle2.append("Aggressive")
    else:
        GameStyle2.append("Supportive")
newdotachamps["GameStyle"]=GameStyle2
print(newdotachamps)
# Out:
#       id  localized_name                                              roles  \
# 0      1       Anti-Mage                       ['Carry', 'Escape', 'Nuker']
# 1      2             Axe    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2      3            Bane        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3      4     Bloodseeker  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4      5  Crystal Maiden        ['Support', 'Disabler', 'Nuker', 'Jungler']
# ..   ...             ...                                                ...
# 107  109     Terrorblade                       ['Carry', 'Pusher', 'Nuker']
# 108  110         Phoenix  ['Support', 'Nuker', 'Initiator', 'Escape', 'D...
# 109  111          Oracle         ['Support', 'Nuker', 'Disabler', 'Escape']
# 110  112   Winter Wyvern                   ['Support', 'Disabler', 'Nuker']
# 111  113      Arc Warden                       ['Carry', 'Escape', 'Nuker']
#
#       GameStyle
# 0    Aggressive
# 1    Supportive
# 2    Supportive
# 3    Aggressive
# 4    Supportive
# ..          ...
# 107  Aggressive
# 108  Supportive
# 109  Supportive
# 110  Supportive
# 111  Aggressive
#
# [112 rows x 4 columns]

# %%
# LOL - MAÇLARDAKİ ŞAMPİYON IDYE GÖRE ŞAMPİYON ÖZELLİKLERİNİ LİSTELEME
participants= pd.merge(participants,champs,how="left",left_on="championid",right_on="id")

print(participants.isnull().count())
participants.head(10)
# Out:
# id_x          1834520
# matchid       1834520
# player        1834520
# championid    1834520
# ss1           1834520
# ss2           1834520
# role          1834520
# position      1834520
# name          1834520
# id_y          1834520
# Name          1834520
# Class         1834520
# GameStyle     1834520
# dtype: int64
#    id_x  matchid  player  championid  ss1  ss2         role position     name  \
# 0     9       10       1          19    4   11         NONE   JUNGLE  Warwick
# 1    10       10       2         267    3    4  DUO_SUPPORT      BOT     Nami
# 2    11       10       3         119    7    4    DUO_CARRY      BOT   Draven
# 3    12       10       4         114   12    4         SOLO      TOP    Fiora
# 4    13       10       5         112    4    3         SOLO      MID   Viktor
# 5    14       10       6          72   11    4         NONE   JUNGLE  Skarner
# 6    15       10       7           3    4   12         SOLO      TOP    Galio
# 7    16       10       8         103   14    4         SOLO      MID     Ahri
# 8    17       10       9         222    7    4    DUO_CARRY      BOT     Jinx
# 9    18       10      10         161   14    4  DUO_SUPPORT      BOT   VelKoz
#
#    id_y     Name     Class   GameStyle
# 0    19  Warwick   Warrior  Aggressive
# 1   267     Nami   Support  Supportive
# 2   119   Draven  Marksman  Aggressive
# 3   114    Fiora   Warrior  Aggressive
# 4   112   Viktor      Mage  Aggressive
# 5    72  Skarner   Warrior  Aggressive
# 6     3    Galio      Mage  Aggressive
# 7   103     Ahri      Mage  Aggressive
# 8   222     Jinx  Marksman  Aggressive
# 9   161   VelKoz      Mage  Aggressive

# %%
# DOTA - MAÇLARDAKİ ŞAMPİYON IDYE GÖRE ŞAMPİYON ÖZELLİKLERİNİ LİSTELEME
dotaplayers= pd.merge(dotaplayers,newdotachamps,how="left",left_on="hero_id",right_on="id")

print(dotaplayers.isnull().count())
dotaplayers.head(10)
# Out:
# match_id               500000
# account_id             500000
# hero_id                500000
# player_slot            500000
# gold                   500000
#                         ...
# unit_order_continue    500000
# id                     500000
# localized_name         500000
# roles                  500000
# GameStyle              500000
# Length: 77, dtype: int64
#    match_id  account_id  hero_id  player_slot  gold  gold_spent  gold_per_min  \
# 0         0           0       86            0  3261       10960           347
# 1         0           1       51            1  2954       17760           494
# 2         0           0       83            2   110       12195           350
# 3         0           2       11            3  1179       22505           599
# 4         0           3       67            4  3307       23825           613
# 5         0           4      106          128   476       12285           397
# 6         0           0      102          129   317       10355           303
# 7         0           5       46          130  2390       13395           452
# 8         0           0        7          131   475        5035           189
# 9         0           6       73          132    60       17550           496
#
#    xp_per_min  kills  deaths  ...  unit_order_move_to_direction  \
# 0         362      9       3  ...                           NaN
# 1         659     13       3  ...                           NaN
# 2         385      0       4  ...                           NaN
# 3         605      8       4  ...                           NaN
# 4         762     20       3  ...                           NaN
# 5         524      5       6  ...                           NaN
# 6         369      4      13  ...                           NaN
# 7         517      4       8  ...                         110.0
# 8         223      1      14  ...                           NaN
# 9         456      1      11  ...                           NaN
#
#    unit_order_patrol  unit_order_vector_target_position unit_order_radar  \
# 0                NaN                                NaN              NaN
# 1                NaN                                NaN              NaN
# 2                NaN                                NaN              NaN
# 3                NaN                                NaN              NaN
# 4                NaN                                NaN              NaN
# 5                NaN                                NaN              NaN
# 6                NaN                                NaN              NaN
# 7                NaN                                NaN              NaN
# 8                NaN                                NaN              NaN
# 9                NaN                                NaN              NaN
#
#    unit_order_set_item_combine_lock  unit_order_continue     id  \
# 0                               NaN                  NaN   86.0
# 1                               NaN                  NaN   51.0
# 2                               NaN                  NaN   83.0
# 3                               NaN                  NaN   11.0
# 4                               NaN                  NaN   67.0
# 5                               NaN                  NaN  106.0
# 6                               NaN                  NaN  102.0
# 7                               NaN                  NaN   46.0
# 8                               NaN                  NaN    7.0
# 9                               NaN                  NaN   73.0
#
#      localized_name                                              roles  \
# 0            Rubick                   ['Support', 'Disabler', 'Nuker']
# 1         Clockwerk      ['Initiator', 'Disabler', 'Durable', 'Nuker']
# 2  Treant Protector  ['Support', 'Initiator', 'Durable', 'Disabler'...
# 3      Shadow Fiend                                 ['Carry', 'Nuker']
# 4           Spectre                     ['Carry', 'Durable', 'Escape']
# 5      Ember Spirit  ['Carry', 'Escape', 'Nuker', 'Disabler', 'Init...
# 6           Abaddon                    ['Support', 'Carry', 'Durable']
# 7  Templar Assassin                                ['Carry', 'Escape']
# 8       Earthshaker      ['Support', 'Initiator', 'Disabler', 'Nuker']
# 9         Alchemist  ['Carry', 'Support', 'Durable', 'Disabler', 'I...
#
#     GameStyle
# 0  Supportive
# 1  Supportive
# 2  Supportive
# 3  Aggressive
# 4  Aggressive
# 5  Aggressive
# 6  Supportive
# 7  Aggressive
# 8  Supportive
# 9  Aggressive
#
# [10 rows x 77 columns]

# %%
# LOL - ŞAMPİYON IDYE GÖRE MAÇLARDA EN ÇOK SEÇİLEN KARAKTERLER
print(participants.championid.count())
print(participants.championid.value_counts())
# Out:
# 1834520
# 64     59286
# 51     57275
# 236    56676
# 412    48877
# 103    37424
#        ...
# 136     2231
# 72      2111
# 82      2107
# 421     2106
# 6       1021
# Name: championid, Length: 136, dtype: int64

# %%
# DOTA - ŞAMPİYON IDYE GÖRE MAÇLARDA EN ÇOK SEÇİLEN KARAKTERLER
print(dotaplayers.hero_id.count())
print(dotaplayers.hero_id.value_counts())
# Out:
# 500000
# 21     20881
# 11     17007
# 74     11676
# 7      11323
# 28     11181
#        ...
# 80       967
# 78       931
# 103      838
# 66       579
# 0         37
# Name: hero_id, Length: 111, dtype: int64

# %%
# LOL - ŞAMPİYON İSMİNE GÖRE MAÇLARDA EN ÇOK SEÇİLEN KARAKTERLER
print(participants.Name.count())
print(participants.Name.value_counts())
# Out:
# 1834520
# Lee Sin         59286
# Caitlyn         57275
# Lucian          56676
# Thresh          48877
# Ahri            37424
#                 ...
# Aurelion Sol     2231
# Skarner          2111
# Mordekaiser      2107
# RekSai           2106
# Urgot            1021
# Name: Name, Length: 136, dtype: int64

# %%
# DOTA - ŞAMPİYON İSMİNE GÖRE MAÇLARDA EN ÇOK SEÇİLEN KARAKTERLER
print(dotaplayers.localized_name.count())
print(dotaplayers.localized_name.value_counts())
# Out:
# 499963
# Windranger      20881
# Shadow Fiend    17007
# Invoker         11676
# Earthshaker     11323
# Slardar         11181
#                 ...
# Lycan             985
# Lone Druid        967
# Brewmaster        931
# Elder Titan       838
# Chen              579
# Name: localized_name, Length: 110, dtype: int64

# %%
# LOL - AGGRESSIVE VE SUPPORTIVE HEROLARIN MAÇLARDA SEÇİLME SAYILARI
print(participants.GameStyle.count())
print(participants.GameStyle.value_counts())
# Out:
# 1834520
# Aggressive    1432911
# Supportive     401609
# Name: GameStyle, dtype: int64

# %%
# DOTA - AGGRESSIVE VE SUPPORTIVE HEROLARIN MAÇLARDA SEÇİLME SAYILARI
print(dotaplayers.GameStyle.count())
print(dotaplayers.GameStyle.value_counts())
# Out:
# 499963
# Aggressive    310108
# Supportive    189855
# Name: GameStyle, dtype: int64

# %%
# LOL - 1800000 MAÇTA SEÇİLEN KARAKTERLERİN AGRO / SUP OLDUĞUNUN PİECHARTI
labels="Aggressive", "Supportive"
colors=["red","#9EF50E"]
class1=participants[participants["GameStyle"]=="Aggressive"].count()[1]
class2=participants[participants["GameStyle"]=="Supportive"].count()[1]
print(class1)
print(class2)
my_data=[class1,class2]
plt.pie(my_data,labels=labels,autopct='%2.f%%',colors=colors)
plt.show()
# Out:
# 1432911
# 401609

# %%
# DOTA - 500000 MAÇTA SEÇİLEN KARAKTERLERİN AGRO / SUP OLDUĞUNUN PİECHARTI
labels="Aggressive", "Supportive"
colors=["red","#9EF50E"]
class1=dotaplayers[dotaplayers["GameStyle"]=="Aggressive"].count()[1]
class2=dotaplayers[dotaplayers["GameStyle"]=="Supportive"].count()[1]
print(class1)
print(class2)
my_data=[class1,class2]
plt.pie(my_data,labels=labels,autopct='%2.f%%',colors=colors)
plt.show()
# Out:
# 310108
# 189855

# %%
# LOL - BANLANAN DATALARI VE NULL VAR MI KONTROLÜ
print(teambans.count())
print(teambans.isnull().count())
teambans.head()
# Out:
# matchid       1099185
# teamid        1099185
# championid    1099185
# banturn       1099185
# dtype: int64
# matchid       1099185
# teamid        1099185
# championid    1099185
# banturn       1099185
# dtype: int64
#    matchid  teamid  championid  banturn
# 0       10     100          11        1
# 1       10     100         117        3
# 2       10     100         120        5
# 3       10     200          84        2
# 4       10     200         201        4

# %%
# LOL - BANLANANLAR TABLOSUYLA CHAMPS İ BİRLEŞTİRİYORUZ
teambans= pd.merge(teambans,champs,how="left",left_on="championid",right_on="id")
print(teambans.isnull().count())
teambans.head()
# Out:
# matchid       1099185
# teamid        1099185
# championid    1099185
# banturn       1099185
# name          1099185
# id            1099185
# Name          1099185
# Class         1099185
# GameStyle     1099185
# dtype: int64
#    matchid  teamid  championid  banturn       name   id       Name    Class  \
# 0       10     100          11        1  Master Yi   11  Master Yi  Assasin
# 1       10     100         117        3       Lulu  117       Lulu  Support
# 2       10     100         120        5    Hecarim  120    Hecarim  Warrior
# 3       10     200          84        2      Akali   84      Akali  Assasin
# 4       10     200         201        4      Braum  201      Braum  Support
#
#     GameStyle
# 0  Aggressive
# 1  Supportive
# 2  Aggressive
# 3  Aggressive
# 4  Supportive

# %%
# LOL - 1000000 MAÇTA banlanan KARAKTERLERİN AGRO / SUP OLDUĞUNUN PİECHARTI
labels="Aggressive", "Supportive"
colors=["red","#9EF50E"]
class1=teambans[teambans["GameStyle"]=="Aggressive"].count()[1]
class2=teambans[teambans["GameStyle"]=="Supportive"].count()[1]
print(class1)
print(class2)
my_data=[class1,class2]
plt.pie(my_data,labels=labels,autopct='%2.f%%',colors=colors)
plt.show()
# Out:
# 898795
# 200390

# %%
# LOL - İSME GÖRE EN ÇOK BANLANAN KARAKTERLER
print(teambans.Name.count())
print(teambans.Name.value_counts())
# Out:
# 1099185
# Yasuo      97862
# Fizz       81525
# Xayah      77293
# Lulu       75421
# Darius     58799
#            ...
# Sion         221
# Nami         161
# Corki        156
# Karthus      122
# Sivir         78
# Name: Name, Length: 136, dtype: int64

# %%
# LOL - İSME GÖRE EN ÇOK SEÇİLEN 10 KARAKTER
participants.Name.value_counts().head(10)
# Out:
# Lee Sin    59286
# Caitlyn    57275
# Lucian     56676
# Thresh     48877
# Ahri       37424
# Vayne      35014
# Yasuo      30257
# Xayah      28944
# Orianna    28594
# Ezreal     28397
# Name: Name, dtype: int64

# %%
# DOTA - İSME GÖRE EN ÇOK SEÇİLEN 10 KARAKTER
dotaplayers.localized_name.value_counts().head(10)
# Out:
# Windranger       20881
# Shadow Fiend     17007
# Invoker          11676
# Earthshaker      11323
# Slardar          11181
# Queen of Pain    10590
# Juggernaut       10394
# Tusk             10306
# Alchemist         9823
# Pudge             9447
# Name: localized_name, dtype: int64

# %%
# LOL - İSME GÖRE EN ÇOK SEÇİLEN 10 KARAKTERİ AYRI ARRAYLERE ATMACA
choosetop=[]
labelchoosetop=[]
print(participants.Name.value_counts().head(10).sum())
for iter in range(10):
    labelchoosetop.append(participants.Name.value_counts().head(10).index[iter])
    choosetop.append(participants.Name.value_counts().head(10)[iter])
print(labelchoosetop)
print(choosetop)
# Out:
# 410744
# ['Lee Sin', 'Caitlyn', 'Lucian', 'Thresh', 'Ahri', 'Vayne', 'Yasuo', 'Xayah', 'Orianna', 'Ezreal']
# [59286, 57275, 56676, 48877, 37424, 35014, 30257, 28944, 28594, 28397]

# %%
# DOTA - İSME GÖRE EN ÇOK SEÇİLEN 10 KARAKTERİ AYRI ARRAYLERE ATMACA
choosetop2=[]
labelchoosetop2=[]
print(dotaplayers.localized_name.value_counts().head(10).sum())
for iter in range(10):
    labelchoosetop2.append(dotaplayers.localized_name.value_counts().head(10).index[iter])
    choosetop2.append(dotaplayers.localized_name.value_counts().head(10)[iter])
print(labelchoosetop2)
print(choosetop2)
# Out:
# 122628
# ['Windranger', 'Shadow Fiend', 'Invoker', 'Earthshaker', 'Slardar', 'Queen of Pain', 'Juggernaut', 'Tusk', 'Alchemist', 'Pudge']
# [20881, 17007, 11676, 11323, 11181, 10590, 10394, 10306, 9823, 9447]

# %%
# LOL - İSME GÖRE EN ÇOK BANLANAN 10 KARAKTERİ AYRI ARRAYLERE ATMACA
bantop=[]
labelbantop=[]
print(teambans.Name.value_counts().head(10))
for iter in range(10):
    labelbantop.append(teambans.Name.value_counts().head(10).index[iter])
    bantop.append(teambans.Name.value_counts().head(10)[iter])
print(labelbantop)
print(bantop)
# Out:
# Yasuo       97862
# Fizz        81525
# Xayah       77293
# Lulu        75421
# Darius      58799
# Sejuani     47063
# Zed         41395
# Katarina    39800
# Fiora       36246
# Ivern       30356
# Name: Name, dtype: int64
# ['Yasuo', 'Fizz', 'Xayah', 'Lulu', 'Darius', 'Sejuani', 'Zed', 'Katarina', 'Fiora', 'Ivern']
# [97862, 81525, 77293, 75421, 58799, 47063, 41395, 39800, 36246, 30356]

# %%
# LOL - TOP 10 SEÇİLENLER BARCHART
plt.figure(figsize=(12, 6))
plt.title('Top 10 selected characters')
plt.bar(labelchoosetop, choosetop, width=0.7,
color=['red', 'red', 'red', '#9EF50E', 'red', 'red', 'red', 'red', 'red', 'red'])
plt.show()

# %%
# DOTA - TOP 10 SEÇİLENLER BARCHART
plt.figure(figsize=(13, 6))
plt.title('Top 10 selected characters')
plt.bar(labelchoosetop2, choosetop2, width=0.7,
color=['red', 'red', 'red', '#9EF50E', 'red', 'red', 'red', '#9EF50E', 'red', '#9EF50E'])
plt.show()

# %%
# LOL - TOP 10 BANLANANLAR BARCHART
plt.figure(figsize = (12,6))
plt.title('Top 10 banned characters')
plt.bar(labelbantop,bantop,width=0.7,color=['red', 'red', 'red', '#9EF50E', 'red', '#9EF50E', 'red', 'red', 'red', 'red'])
plt.show()

# %%
# LOL - KMEANS için df_stats belirleme
df_stats=stats[["id","kills","assists","deaths"]]

x = df_stats.iloc[:, [1, 2]].values

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

#Visualising the clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', label = '0')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'orange', label = '1')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'lime', label = '2')
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s = 100, c = 'black', label = '3')
plt.scatter(x[y_kmeans == 4, 0], x[y_kmeans == 4, 1], s = 100, c = 'green', label = '4')

# dağılımdaki kümelerdeki eleman sayıları, buradan agresif/supportive/iyi kötü/bencil olup olmadığı gibi sonuçlar çıkacak.
print("0.küme -> " + str(len(x[y_kmeans == 0, 0])))
print("1.küme -> " + str(len(x[y_kmeans == 1, 0])))
print("2.küme -> " + str(len(x[y_kmeans == 2, 0])))
print("3.küme -> " + str(len(x[y_kmeans == 3, 0])))
print("4.küme -> " + str(len(x[y_kmeans == 4, 0])))

#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'gold', marker='^', label = 'Centroids')

plt.legend()
# Out:
# 0.küme -> 233901
# 1.küme -> 312281
# 2.küme -> 245914
# 3.küme -> 88573
# 4.küme -> 119330

# %%
x = df_stats["kills"]
y = df_stats["assists"]
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
density = ax.scatter_density(x, y,dpi=6)
ax.set_xlim(0, 50)
ax.set_ylim(0, 50)
fig.colorbar(density, label='Number of points per pixel')
# Out:
# c:\users\casper\appdata\local\programs\python\python38\lib\site-packages\mpl_scatter_density\generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# c:\users\casper\appdata\local\programs\python\python38\lib\site-packages\mpl_scatter_density\generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %%
# DOTA - KMEANS için df_stats belirleme
df_dotaplayers=dotaplayers[["kills","assists"]]

x = df_dotaplayers.values

# %%
dota_kmeans = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_dotakmeans = dota_kmeans.fit_predict(x)

#Visualising the clusters
plt.scatter(x[y_dotakmeans == 0, 0], x[y_dotakmeans == 0, 1], s = 100, c = 'lime', label = '0')
plt.scatter(x[y_dotakmeans == 1, 0], x[y_dotakmeans == 1, 1], s = 100, c = 'red', label = '1')
plt.scatter(x[y_dotakmeans == 2, 0], x[y_dotakmeans == 2, 1], s = 100, c = 'green', label = '2')
plt.scatter(x[y_dotakmeans == 3, 0], x[y_dotakmeans == 3, 1], s = 100, c = 'orange', label = '3')
plt.scatter(x[y_dotakmeans == 4, 0], x[y_dotakmeans == 4, 1], s = 100, c = 'black', label = '4')

# dağılımdaki kümelerdeki eleman sayıları, buradan agresif/supportive/iyi kötü/bencil olup olmadığı gibi sonuçlar çıkacak.
print("0.küme -> " + str(len(x[y_dotakmeans == 0, 0])))
print("1.küme -> " + str(len(x[y_dotakmeans == 1, 0])))
print("2.küme -> " + str(len(x[y_dotakmeans == 2, 0])))
print("3.küme -> " + str(len(x[y_dotakmeans == 3, 0])))
print("4.küme -> " + str(len(x[y_dotakmeans == 4, 0])))

#Plotting the centroids of the clusters
plt.scatter(dota_kmeans.cluster_centers_[:, 0], dota_kmeans.cluster_centers_[:,1], s = 100, c = 'gold', marker='^', label = 'Centroids')

plt.legend()
# Out:
# 0.küme -> 142853
# 1.küme -> 91034
# 2.küme -> 53280
# 3.küme -> 148700
# 4.küme -> 64133

# %%
x = df_dotaplayers["kills"]
y = df_dotaplayers["assists"]
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
density = ax.scatter_density(x, y,dpi=6)
ax.set_xlim(0, 50)
ax.set_ylim(0, 50)
fig.colorbar(density, label='Number of points per pixel')
# Out:
# c:\users\casper\appdata\local\programs\python\python38\lib\site-packages\mpl_scatter_density\generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# c:\users\casper\appdata\local\programs\python\python38\lib\site-packages\mpl_scatter_density\generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %%
participants.head(10)
# Out:
#    id_x  matchid  player  championid  ss1  ss2         role position     name  \
# 0     9       10       1          19    4   11         NONE   JUNGLE  Warwick
# 1    10       10       2         267    3    4  DUO_SUPPORT      BOT     Nami
# 2    11       10       3         119    7    4    DUO_CARRY      BOT   Draven
# 3    12       10       4         114   12    4         SOLO      TOP    Fiora
# 4    13       10       5         112    4    3         SOLO      MID   Viktor
# 5    14       10       6          72   11    4         NONE   JUNGLE  Skarner
# 6    15       10       7           3    4   12         SOLO      TOP    Galio
# 7    16       10       8         103   14    4         SOLO      MID     Ahri
# 8    17       10       9         222    7    4    DUO_CARRY      BOT     Jinx
# 9    18       10      10         161   14    4  DUO_SUPPORT      BOT   VelKoz
#
#    id_y     Name     Class   GameStyle
# 0    19  Warwick   Warrior  Aggressive
# 1   267     Nami   Support  Supportive
# 2   119   Draven  Marksman  Aggressive
# 3   114    Fiora   Warrior  Aggressive
# 4   112   Viktor      Mage  Aggressive
# 5    72  Skarner   Warrior  Aggressive
# 6     3    Galio      Mage  Aggressive
# 7   103     Ahri      Mage  Aggressive
# 8   222     Jinx  Marksman  Aggressive
# 9   161   VelKoz      Mage  Aggressive

# %%
stats_tree=stats[["id","kills","deaths","assists"]]
stats_tree.head(10)
# Out:
#    id  kills  deaths  assists
# 0   9      6      10        1
# 1  10      0       2       12
# 2  11      7       8        5
# 3  12      5      11        2
# 4  13      2       8        2
# 5  14      3       3        9
# 6  15      4       5       11
# 7  16     13       4        8
# 8  17     15       3        9
# 9  18      4       5       19

# %%
participants_tree= pd.merge(participants,stats_tree,how="inner",left_on="id_x",right_on="id")
print(participants_tree.isnull().count())
participants_tree.head(10)
# Out:
# id_x          999999
# matchid       999999
# player        999999
# championid    999999
# ss1           999999
# ss2           999999
# role          999999
# position      999999
# name          999999
# id_y          999999
# Name          999999
# Class         999999
# GameStyle     999999
# id            999999
# kills         999999
# deaths        999999
# assists       999999
# dtype: int64
#    id_x  matchid  player  championid  ss1  ss2         role position     name  \
# 0     9       10       1          19    4   11         NONE   JUNGLE  Warwick
# 1    10       10       2         267    3    4  DUO_SUPPORT      BOT     Nami
# 2    11       10       3         119    7    4    DUO_CARRY      BOT   Draven
# 3    12       10       4         114   12    4         SOLO      TOP    Fiora
# 4    13       10       5         112    4    3         SOLO      MID   Viktor
# 5    14       10       6          72   11    4         NONE   JUNGLE  Skarner
# 6    15       10       7           3    4   12         SOLO      TOP    Galio
# 7    16       10       8         103   14    4         SOLO      MID     Ahri
# 8    17       10       9         222    7    4    DUO_CARRY      BOT     Jinx
# 9    18       10      10         161   14    4  DUO_SUPPORT      BOT   VelKoz
#
#    id_y     Name     Class   GameStyle  id  kills  deaths  assists
# 0    19  Warwick   Warrior  Aggressive   9      6      10        1
# 1   267     Nami   Support  Supportive  10      0       2       12
# 2   119   Draven  Marksman  Aggressive  11      7       8        5
# 3   114    Fiora   Warrior  Aggressive  12      5      11        2
# 4   112   Viktor      Mage  Aggressive  13      2       8        2
# 5    72  Skarner   Warrior  Aggressive  14      3       3        9
# 6     3    Galio      Mage  Aggressive  15      4       5       11
# 7   103     Ahri      Mage  Aggressive  16     13       4        8
# 8   222     Jinx  Marksman  Aggressive  17     15       3        9
# 9   161   VelKoz      Mage  Aggressive  18      4       5       19

# %%
participants_tree=participants_tree[["championid","kills","deaths","assists"]]
participants_tree.head(10)
# Out:
#    championid  kills  deaths  assists
# 0          19      6      10        1
# 1         267      0       2       12
# 2         119      7       8        5
# 3         114      5      11        2
# 4         112      2       8        2
# 5          72      3       3        9
# 6           3      4       5       11
# 7         103     13       4        8
# 8         222     15       3        9
# 9         161      4       5       19

# %%
participants_means=participants_tree.groupby(by=["championid"]).mean()
participants_means.head(10)
# Out:
#                kills    deaths   assists
# championid
# 1           6.839387  6.426132  7.569396
# 2           6.222863  5.883766  6.596542
# 3           3.833447  5.452267  9.893368
# 4           6.150146  6.303213  7.651607
# 5           6.701913  6.601474  6.321355
# 6           5.380952  5.827839  5.864469
# 7           7.772672  5.684595  5.970061
# 8           6.028019  5.940366  6.181450
# 9           5.250755  6.192749  9.452870
# 10          5.418950  6.009418  6.289669

# %%
champs.head(5)
# Out:
#        name   id      Name     Class   GameStyle
# 0       Jax   24       Jax   Warrior  Aggressive
# 1      Sona   37      Sona   Support  Supportive
# 2  Tristana   18  Tristana  Marksman  Aggressive
# 3     Varus  110     Varus  Marksman  Aggressive
# 4     Fiora  114     Fiora   Warrior  Aggressive

# %%
participants_tree2= pd.merge(participants_means,champs,how="left",left_on="championid",right_on="id")
participants_tree2.head(50).sort_values(by=["assists"], ascending=False)
# Out:
#        kills    deaths    assists          name  id          Name     Class  \
# 43  1.468571  4.839481  14.046753         Taric  44         Taric   Support
# 39  0.850101  3.935479  13.996774         Janna  40         Janna   Support
# 15  0.903585  4.976635  13.896603        Soraka  16        Soraka   Support
# 36  2.854832  5.483219  13.318507          Sona  37          Sona   Support
# 11  1.914720  5.486558  12.937197       Alistar  12       Alistar   Support
# 24  3.200398  5.570575  12.861339       Morgana  25       Morgana   Support
# 48  2.417912  5.514940  12.584711    Blitzcrank  53    Blitzcrank   Support
# 42  2.440296  5.117718  12.150264         Karma  43         Karma   Support
# 25  3.121084  4.581325  11.458735        Zilean  26        Zilean   Support
# 31  4.544060  5.290407  10.560556         Amumu  32         Amumu      Tank
# 19  3.369153  4.913559  10.381356          Nunu  20          Nunu      Tank
# 32  4.230066  5.696781  10.273592        Rammus  33        Rammus      Tank
# 2   3.833447  5.452267   9.893368         Galio   3         Galio      Mage
# 13  4.142648  5.826916   9.802714          Sion  14          Sion   Warrior
# 8   5.250755  6.192749   9.452870  Fiddlesticks   9  Fiddlesticks      Mage
# 49  4.701021  4.902507   8.722377      Malphite  54      Malphite      Tank
# 29  7.572767  6.923173   8.550281       Karthus  30       Karthus      Mage
# 21  5.683501  5.998214   8.403134          Ashe  22          Ashe  Marksman
# 14  5.713815  5.546299   8.281690         Sivir  15         Sivir  Marksman
# 20  7.150953  6.009527   8.154912  Miss Fortune  21  Miss Fortune  Marksman
# 27  7.818182  6.073910   7.933728       Evelynn  28       Evelynn   Assasin
# 3   6.150146  6.303213   7.651607  Twisted Fate   4  Twisted Fate   Assasin
# 45  4.716216  5.345760   7.596459       Trundle  48       Trundle   Warrior
# 0   6.839387  6.426132   7.569396         Annie   1         Annie      Mage
# 41  7.328173  6.286894   7.562436         Corki  42         Corki  Marksman
# 18  6.917576  6.014188   7.446385       Warwick  19       Warwick   Warrior
# 46  5.420420  5.615916   7.435517         Swain  50         Swain      Mage
# 40  6.002417  5.504256   7.330987     Gangplank  41     Gangplank   Warrior
# 26  3.821322  6.706968   7.313877        Singed  27        Singed   Warrior
# 33  6.199728  4.625000   7.292572        Anivia  34        Anivia      Mage
# 34  6.759842  5.568779   7.230430         Shaco  35         Shaco   Assasin
# 47  6.269585  5.652169   7.218877       Caitlyn  51       Caitlyn  Marksman
# 35  5.027805  5.520854   7.172790       DrMundo  36       DrMundo   Warrior
# 28  8.445143  6.149390   7.076015        Twitch  29        Twitch  Marksman
# 44  7.447782  6.164825   6.789572        Veigar  45        Veigar      Mage
# 1   6.222863  5.883766   6.596542          Olaf   2          Olaf   Warrior
# 17  7.377788  5.630323   6.361254      Tristana  18      Tristana  Marksman
# 4   6.701913  6.601474   6.321355      Xin Zhao   5      Xin Zhao   Warrior
# 30  6.139995  5.347685   6.303276       ChoGath  31       ChoGath   Warrior
# 9   5.418950  6.009418   6.289669         Kayle  10         Kayle      Mage
# 7   6.028019  5.940366   6.181450      Vladimir   8      Vladimir   Warrior
# 16  5.972045  6.644130   6.014432         Teemo  17         Teemo   Assasin
# 6   7.772672  5.684595   5.970061       LeBlanc   7       LeBlanc   Assasin
# 37  7.877887  5.393285   5.956694      Kassadin  38      Kassadin   Assasin
# 12  5.101625  6.134462   5.911165          Ryze  13          Ryze      Mage
# 5   5.380952  5.827839   5.864469         Urgot   6         Urgot   Warrior
# 38  7.015306  5.886161   5.482143        Irelia  39        Irelia   Warrior
# 23  6.481975  6.170028   5.258556           Jax  24           Jax   Warrior
# 10  8.679869  6.887673   4.856747     Master Yi  11     Master Yi   Assasin
# 22  6.122329  5.712090   4.485018    Tryndamere  23    Tryndamere   Warrior
#
#      GameStyle
# 43  Supportive
# 39  Supportive
# 15  Supportive
# 36  Supportive
# 11  Supportive
# 24  Supportive
# 48  Supportive
# 42  Supportive
# 25  Supportive
# 31  Supportive
# 19  Supportive
# 32  Supportive
# 2   Aggressive
# 13  Aggressive
# 8   Aggressive
# 49  Supportive
# 29  Aggressive
# 21  Aggressive
# 14  Aggressive
# 20  Aggressive
# 27  Aggressive
# 3   Aggressive
# 45  Aggressive
# 0   Aggressive
# 41  Aggressive
# 18  Aggressive
# 46  Aggressive
# 40  Aggressive
# 26  Aggressive
# 33  Aggressive
# 34  Aggressive
# 47  Aggressive
# 35  Aggressive
# 28  Aggressive
# 44  Aggressive
# 1   Aggressive
# 17  Aggressive
# 4   Aggressive
# 30  Aggressive
# 9   Aggressive
# 7   Aggressive
# 16  Aggressive
# 6   Aggressive
# 37  Aggressive
# 12  Aggressive
# 5   Aggressive
# 38  Aggressive
# 23  Aggressive
# 10  Aggressive
# 22  Aggressive

# %%
participants_tree3=participants_tree2[["kills","deaths","assists","GameStyle"]]
X = participants_tree3.drop(["GameStyle"], axis = 1)
Y= participants_tree3["GameStyle"]

# %%
print(X)
# Out:
#         kills    deaths    assists
# 0    6.839387  6.426132   7.569396
# 1    6.222863  5.883766   6.596542
# 2    3.833447  5.452267   9.893368
# 3    6.150146  6.303213   7.651607
# 4    6.701913  6.601474   6.321355
# ..        ...       ...        ...
# 131  2.589975  4.031224  13.018694
# 132  7.632767  6.345500   6.541098
# 133  3.261449  5.719268  13.168297
# 134  1.431607  5.407344  13.834880
# 135  6.894287  5.920240   7.013897
#
# [136 rows x 3 columns]

# %%
print(Y)
# Out:
# 0      Aggressive
# 1      Aggressive
# 2      Aggressive
# 3      Aggressive
# 4      Aggressive
#           ...
# 131    Aggressive
# 132    Aggressive
# 133    Supportive
# 134    Supportive
# 135    Aggressive
# Name: GameStyle, Length: 136, dtype: object

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=2)

clf = DecisionTreeClassifier(max_depth = 5, random_state = 0)
clf.fit(X_train, Y_train)
Y_pred = clf.predict(X_test)
Y_pred
# Out:
# array(['Aggressive', 'Aggressive', 'Aggressive', 'Aggressive',
#        'Aggressive', 'Aggressive', 'Aggressive', 'Supportive',
#        'Aggressive', 'Aggressive', 'Supportive', 'Aggressive',
#        'Aggressive', 'Supportive', 'Supportive', 'Aggressive',
#        'Aggressive', 'Aggressive', 'Aggressive', 'Aggressive',
#        'Supportive', 'Aggressive', 'Aggressive', 'Aggressive',
#        'Supportive', 'Supportive', 'Aggressive', 'Aggressive',
#        'Supportive', 'Aggressive', 'Supportive', 'Aggressive',
#        'Supportive', 'Aggressive', 'Aggressive', 'Aggressive',
#        'Aggressive', 'Aggressive', 'Aggressive', 'Supportive',
#        'Aggressive'], dtype=object)

# %%
# LOL - Visualizing decision trees using Graphviz
fn=['kills', 'deaths', 'assists']
cn=['Aggressive', 'Supportive']
dot_data = tree.export_graphviz(clf, out_file = None, feature_names = fn, class_names = cn, filled = True, 
                                rounded = True, special_characters = True)
graphviz.Source(dot_data)

# %%
#Confusion matrix
cf_matrix = metrics.confusion_matrix(Y_test, Y_pred)
print(cf_matrix)
# Out:
# [[30  3]
#  [ 0  8]]

# %%
#Accuracy, precision, recall, and f-1 score
print(metrics.classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   Aggressive       1.00      0.91      0.95        33
#   Supportive       0.73      1.00      0.84         8
#
#     accuracy                           0.93        41
#    macro avg       0.86      0.95      0.90        41
# weighted avg       0.95      0.93      0.93        41

# %%
dotaplayers.head(10)
# Out:
#    match_id  account_id  hero_id  player_slot  gold  gold_spent  gold_per_min  \
# 0         0           0       86            0  3261       10960           347
# 1         0           1       51            1  2954       17760           494
# 2         0           0       83            2   110       12195           350
# 3         0           2       11            3  1179       22505           599
# 4         0           3       67            4  3307       23825           613
# 5         0           4      106          128   476       12285           397
# 6         0           0      102          129   317       10355           303
# 7         0           5       46          130  2390       13395           452
# 8         0           0        7          131   475        5035           189
# 9         0           6       73          132    60       17550           496
#
#    xp_per_min  kills  deaths  ...  unit_order_move_to_direction  \
# 0         362      9       3  ...                           NaN
# 1         659     13       3  ...                           NaN
# 2         385      0       4  ...                           NaN
# 3         605      8       4  ...                           NaN
# 4         762     20       3  ...                           NaN
# 5         524      5       6  ...                           NaN
# 6         369      4      13  ...                           NaN
# 7         517      4       8  ...                         110.0
# 8         223      1      14  ...                           NaN
# 9         456      1      11  ...                           NaN
#
#    unit_order_patrol  unit_order_vector_target_position unit_order_radar  \
# 0                NaN                                NaN              NaN
# 1                NaN                                NaN              NaN
# 2                NaN                                NaN              NaN
# 3                NaN                                NaN              NaN
# 4                NaN                                NaN              NaN
# 5                NaN                                NaN              NaN
# 6                NaN                                NaN              NaN
# 7                NaN                                NaN              NaN
# 8                NaN                                NaN              NaN
# 9                NaN                                NaN              NaN
#
#    unit_order_set_item_combine_lock  unit_order_continue     id  \
# 0                               NaN                  NaN   86.0
# 1                               NaN                  NaN   51.0
# 2                               NaN                  NaN   83.0
# 3                               NaN                  NaN   11.0
# 4                               NaN                  NaN   67.0
# 5                               NaN                  NaN  106.0
# 6                               NaN                  NaN  102.0
# 7                               NaN                  NaN   46.0
# 8                               NaN                  NaN    7.0
# 9                               NaN                  NaN   73.0
#
#      localized_name                                              roles  \
# 0            Rubick                   ['Support', 'Disabler', 'Nuker']
# 1         Clockwerk      ['Initiator', 'Disabler', 'Durable', 'Nuker']
# 2  Treant Protector  ['Support', 'Initiator', 'Durable', 'Disabler'...
# 3      Shadow Fiend                                 ['Carry', 'Nuker']
# 4           Spectre                     ['Carry', 'Durable', 'Escape']
# 5      Ember Spirit  ['Carry', 'Escape', 'Nuker', 'Disabler', 'Init...
# 6           Abaddon                    ['Support', 'Carry', 'Durable']
# 7  Templar Assassin                                ['Carry', 'Escape']
# 8       Earthshaker      ['Support', 'Initiator', 'Disabler', 'Nuker']
# 9         Alchemist  ['Carry', 'Support', 'Durable', 'Disabler', 'I...
#
#     GameStyle
# 0  Supportive
# 1  Supportive
# 2  Supportive
# 3  Aggressive
# 4  Aggressive
# 5  Aggressive
# 6  Supportive
# 7  Aggressive
# 8  Supportive
# 9  Aggressive
#
# [10 rows x 77 columns]

# %%
dotaplayers_tree=dotaplayers[["hero_id","kills","deaths","assists"]]
dotaplayers_tree.head(10)
# Out:
#    hero_id  kills  deaths  assists
# 0       86      9       3       18
# 1       51     13       3       18
# 2       83      0       4       15
# 3       11      8       4       19
# 4       67     20       3       17
# 5      106      5       6        8
# 6      102      4      13        5
# 7       46      4       8        6
# 8        7      1      14        8
# 9       73      1      11        6

# %%
dotaplayers_means=dotaplayers_tree.groupby(by=["hero_id"]).mean()
dotaplayers_means.head(10)
# Out:
#             kills    deaths    assists
# hero_id
# 0        0.000000  0.000000   0.000000
# 1        7.340996  5.449979   6.722222
# 2        8.525321  9.365138  10.498153
# 3        4.766941  7.721112  11.811986
# 4        9.657307  9.190122   9.746279
# 5        4.483686  8.946215  14.027402
# 6        6.869248  7.980061   7.801380
# 7        4.931202  8.514616  15.178221
# 8        9.552627  6.439099   8.394939
# 9        6.374480  6.957143  12.395978

# %%
dotaplayers_tree2 = pd.merge(dotaplayers_means,newdotachamps,how="left",left_on="hero_id",right_on="id")
dotaplayers_tree2.head(50).sort_values(by=["assists"], ascending=False)
# Out:
#         kills    deaths    assists    id    localized_name  \
# 22  10.025278  7.576814  18.238178  22.0              Zeus
# 39   5.363184  9.451078  17.505804  40.0        Venomancer
# 35   8.765622  7.995812  15.270565  36.0         Necrophos
# 28   4.201667  7.491667  15.233333  29.0        Tidehunter
# 7    4.931202  8.514616  15.178221   7.0       Earthshaker
# 32   4.416440  7.364095  15.151221  33.0            Enigma
# 16   5.474286  8.010794  14.446667  16.0         Sand King
# 13   8.373651  8.253265  14.290176  13.0              Puck
# 20   4.087744  8.633286  14.141869  20.0   Vengeful Spirit
# 5    4.483686  8.946215  14.027402   5.0    Crystal Maiden
# 29   5.791968  8.706734  13.071985  30.0      Witch Doctor
# 37   5.455987  7.912768  13.011895  38.0       Beastmaster
# 44   5.877792  9.442181  12.687911  45.0             Pugna
# 27   6.121993  7.578839  12.655487  28.0           Slardar
# 36   5.334580  7.645644  12.638696  37.0           Warlock
# 30   5.601878  7.397482  12.551312  31.0              Lich
# 26   4.247701  9.792979  12.546392  27.0     Shadow Shaman
# 23   6.725521  7.871412  12.499410  23.0            Kunkka
# 9    6.374480  6.957143  12.395978   9.0            Mirana
# 15   8.484383  7.811106  12.203768  15.0             Razor
# 14   8.821636  9.676723  12.184609  14.0             Pudge
# 34   8.903649  7.844579  11.913888  35.0            Sniper
# 41   7.865538  5.665897  11.854632  42.0       Wraith King
# 3    4.766941  7.721112  11.811986   3.0              Bane
# 46   9.802439  7.340108  11.769377  47.0             Viper
# 38  10.824551  6.988952  11.620774  39.0     Queen of Pain
# 48   7.004167  7.313021  11.585417  49.0     Dragon Knight
# 17   9.036145  8.093477  11.530951  17.0      Storm Spirit
# 33  10.509962  7.272797  11.491571  34.0            Tinker
# 19   9.901791  7.622243  11.183977  19.0              Tiny
# 25   4.716473  8.987673  10.894744  26.0              Lion
# 42   8.024404  7.744335  10.871586  43.0     Death Prophet
# 49   2.641319  7.540640  10.853624  50.0            Dazzle
# 47   8.515139  7.209420  10.824643  48.0              Luna
# 18   8.242029  7.642609  10.531884  18.0              Sven
# 2    8.525321  9.365138  10.498153   2.0               Axe
# 24   8.971532  8.634888  10.048819  25.0              Lina
# 43   9.781868  7.336126  10.042033  44.0  Phantom Assassin
# 11  10.304933  7.242900   9.994120  11.0      Shadow Fiend
# 21   9.061491  6.874000   9.979407  21.0        Windranger
# 10   7.646982  5.837927   9.759186  10.0         Morphling
# 4    9.657307  9.190122   9.746279   4.0       Bloodseeker
# 12   7.573973  6.589315   9.516438  12.0    Phantom Lancer
# 31  12.713768  7.065942   9.501208  32.0              Riki
# 40   8.223301  7.211087   8.652365  41.0     Faceless Void
# 8    9.552627  6.439099   8.394939   8.0        Juggernaut
# 45  10.810659  6.450844   7.894075  46.0  Templar Assassin
# 6    6.869248  7.980061   7.801380   6.0       Drow Ranger
# 1    7.340996  5.449979   6.722222   1.0         Anti-Mage
# 0    0.000000  0.000000   0.000000   NaN               NaN
#
#                                                 roles   GameStyle
# 22                                          ['Nuker']  Aggressive
# 39  ['Support', 'Nuker', 'Initiator', 'Pusher', 'D...  Supportive
# 35          ['Carry', 'Nuker', 'Durable', 'Disabler']  Aggressive
# 28      ['Initiator', 'Durable', 'Disabler', 'Nuker']  Supportive
# 7       ['Support', 'Initiator', 'Disabler', 'Nuker']  Supportive
# 32     ['Disabler', 'Jungler', 'Initiator', 'Pusher']  Supportive
# 16  ['Initiator', 'Disabler', 'Support', 'Nuker', ...  Supportive
# 13       ['Initiator', 'Disabler', 'Escape', 'Nuker']  Supportive
# 20  ['Support', 'Initiator', 'Disabler', 'Nuker', ...  Supportive
# 5         ['Support', 'Disabler', 'Nuker', 'Jungler']  Supportive
# 29                   ['Support', 'Nuker', 'Disabler']  Supportive
# 37      ['Initiator', 'Disabler', 'Durable', 'Nuker']  Supportive
# 44                                ['Nuker', 'Pusher']  Aggressive
# 27  ['Carry', 'Durable', 'Initiator', 'Disabler', ...  Aggressive
# 36               ['Support', 'Initiator', 'Disabler']  Supportive
# 30                               ['Support', 'Nuker']  Supportive
# 26  ['Support', 'Pusher', 'Disabler', 'Nuker', 'In...  Supportive
# 23  ['Carry', 'Support', 'Disabler', 'Initiator', ...  Aggressive
# 9   ['Carry', 'Support', 'Escape', 'Nuker', 'Disab...  Aggressive
# 15            ['Carry', 'Durable', 'Nuker', 'Pusher']  Aggressive
# 14      ['Disabler', 'Initiator', 'Durable', 'Nuker']  Supportive
# 34                                 ['Carry', 'Nuker']  Aggressive
# 41  ['Carry', 'Support', 'Durable', 'Disabler', 'I...  Aggressive
# 3         ['Support', 'Disabler', 'Nuker', 'Durable']  Supportive
# 46      ['Carry', 'Durable', 'Initiator', 'Disabler']  Aggressive
# 38                       ['Carry', 'Nuker', 'Escape']  Aggressive
# 48  ['Carry', 'Pusher', 'Durable', 'Disabler', 'In...  Aggressive
# 17  ['Carry', 'Escape', 'Nuker', 'Initiator', 'Dis...  Aggressive
# 33                       ['Carry', 'Nuker', 'Pusher']  Aggressive
# 19  ['Carry', 'Nuker', 'Pusher', 'Initiator', 'Dur...  Aggressive
# 25      ['Support', 'Disabler', 'Nuker', 'Initiator']  Supportive
# 42           ['Carry', 'Pusher', 'Nuker', 'Disabler']  Aggressive
# 49                   ['Support', 'Nuker', 'Disabler']  Supportive
# 47                       ['Carry', 'Nuker', 'Pusher']  Aggressive
# 18  ['Carry', 'Disabler', 'Initiator', 'Durable', ...  Aggressive
# 2     ['Initiator', 'Durable', 'Disabler', 'Jungler']  Supportive
# 24          ['Support', 'Carry', 'Nuker', 'Disabler']  Supportive
# 43                                ['Carry', 'Escape']  Aggressive
# 11                                 ['Carry', 'Nuker']  Aggressive
# 21  ['Carry', 'Support', 'Disabler', 'Escape', 'Nu...  Aggressive
# 10  ['Carry', 'Escape', 'Durable', 'Nuker', 'Disab...  Aggressive
# 4   ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...  Aggressive
# 12             ['Carry', 'Escape', 'Pusher', 'Nuker']  Aggressive
# 31                    ['Carry', 'Escape', 'Disabler']  Aggressive
# 40  ['Carry', 'Initiator', 'Disabler', 'Escape', '...  Aggressive
# 8                       ['Carry', 'Pusher', 'Escape']  Aggressive
# 45                                ['Carry', 'Escape']  Aggressive
# 6                     ['Carry', 'Disabler', 'Pusher']  Aggressive
# 1                        ['Carry', 'Escape', 'Nuker']  Aggressive
# 0                                                 NaN         NaN

# %%
dotaplayers_tree3=dotaplayers_tree2[["kills","deaths","assists","GameStyle"]]
x = dotaplayers_tree3.drop(["GameStyle"], axis = 1)
y = dotaplayers_tree3["GameStyle"]

# %%
print(x)
# Out:
#         kills    deaths    assists
# 0    0.000000  0.000000   0.000000
# 1    7.340996  5.449979   6.722222
# 2    8.525321  9.365138  10.498153
# 3    4.766941  7.721112  11.811986
# 4    9.657307  9.190122   9.746279
# ..        ...       ...        ...
# 106  5.356838  7.667023  15.289530
# 107  7.531915  7.255964   9.275306
# 108  6.465170  7.988775  15.667217
# 109  5.663033  7.887017   9.775025
# 110  3.637911  7.674678  12.228401
#
# [111 rows x 3 columns]

# %%
print(y)
# Out:
# 0             NaN
# 1      Aggressive
# 2      Supportive
# 3      Supportive
# 4      Aggressive
#           ...
# 106    Aggressive
# 107    Aggressive
# 108    Supportive
# 109    Supportive
# 110    Supportive
# Name: GameStyle, Length: 111, dtype: object

# %%
X_traindota, X_testdota, Y_traindota, Y_testdota = train_test_split(x, y, test_size=0.30, random_state=2)

clf_dota = DecisionTreeClassifier(max_depth = 5, random_state = 0)
clf_dota.fit(X_traindota, Y_traindota)
Y_preddota = clf_dota.predict(X_testdota)
Y_preddota
# Out:
# array(['Supportive', 'Supportive', 'Aggressive', 'Aggressive',
#        'Supportive', 'Aggressive', 'Supportive', 'Supportive',
#        'Supportive', 'Aggressive', 'Aggressive', 'Supportive',
#        'Aggressive', 'Aggressive', 'Supportive', 'Aggressive',
#        'Aggressive', 'Supportive', 'Aggressive', 'Aggressive',
#        'Supportive', 'Aggressive', 'Supportive', 'Supportive',
#        'Aggressive', 'Supportive', 'Supportive', 'Aggressive',
#        'Aggressive', 'Supportive', 'Supportive', 'Aggressive',
#        'Supportive', 'Supportive'], dtype=object)

# %%
# DOTA - Visualizing decision trees using Graphviz
fn=['kills', 'deaths', 'assists']
cn=['Aggressive', 'Supportive']
dota_dot_data = tree.export_graphviz(clf_dota, out_file = None, feature_names = fn, class_names = cn, filled = True, 
                                rounded = True, special_characters = True)
graphviz.Source(dota_dot_data)
